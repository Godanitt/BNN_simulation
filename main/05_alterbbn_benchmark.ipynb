# %% [markdown]
# # 05 — Benchmark con AlterBBN y comparación combinada
#
# Este notebook no recalcula AlterBBN: toma la salida que se obtuvo con `./stand_cosmo.x 5`, la guarda en CSV y genera las tablas/figuras combinadas:
#
# - `pynucastro` vs `AlterBBN` vs observación,
# - tabla compacta de resultados AlterBBN,
# - matriz de correlación de AlterBBN,
# - figuras finales usadas por la memoria.
#
# Debe ejecutarse **después** de los notebooks 00–04, porque lee los CSV finales de `pynucastro` y sobrescribe las figuras/tablas comparativas con la versión que incluye AlterBBN.

# %%
from pathlib import Path
import subprocess
import sys

script = Path('05_make_alterbbn_benchmark.py')
if not script.exists():
    raise FileNotFoundError(script)

subprocess.run([sys.executable, str(script)], check=True)
# Out:
# Wrote AlterBBN/model benchmark tables and figures.
#      model   Yp_He4          D/H    He3/H        Li7/H        Li6/H        Be7/H                   source
# pynucastro 0.249888 5.585615e-09 0.000005 9.465500e-08          NaN 9.465500e-08 pynucastro light network
#   AlterBBN 0.252500 2.674000e-05 0.000011 4.972000e-10 1.211000e-14 4.652000e-10 AlterBBN stand_cosmo.x 5
# CompletedProcess(args=['/home/daniel/.venv/bin/python3', '05_make_alterbbn_benchmark.py'], returncode=0)

# %%
import pandas as pd

print('AlterBBN:')
display(pd.read_csv('data/alterbbn_standard_results.csv'))

print('Comparación combinada:')
display(pd.read_csv('data/comparison_pynucastro_alterbbn_observed.csv'))

print('Resumen final:')
display(pd.read_csv('data/bbn_final_benchmark_combined.csv'))
# Out:
# AlterBBN:
#   observable   display alterbbn_column           low          cent  \
# 0     Yp_He4     $Y_p$              Yp  2.521000e-01  2.525000e-01
# 1        D/H       D/H            H2/H  2.766000e-05  2.674000e-05
# 2      He3/H  $^3$He/H           He3/H  1.056000e-05  1.067000e-05
# 3      Li7/H  $^7$Li/H           Li7/H  4.582000e-10  4.972000e-10
# 4      Li6/H  $^6$Li/H           Li6/H  1.903000e-15  1.211000e-14
# 5      Be7/H  $^7$Be/H           Be7/H  4.268000e-10  4.652000e-10
#
#            high         value         sigma                    source  \
# 0  2.525000e-01  2.525000e-01  3.280000e-04  AlterBBN stand_cosmo.x 5
# 1  2.558000e-05  2.674000e-05  5.462000e-07  AlterBBN stand_cosmo.x 5
# 2  1.068000e-05  1.067000e-05  1.730000e-07  AlterBBN stand_cosmo.x 5
# 3  5.497000e-10  4.972000e-10  3.616000e-11  AlterBBN stand_cosmo.x 5
# 4  3.843000e-14  1.211000e-14  1.219000e-14  AlterBBN stand_cosmo.x 5
# 5  5.179000e-10  4.652000e-10  3.548000e-11  AlterBBN stand_cosmo.x 5
#
#                                                notes
# 0                 Primordial helium-4 mass fraction.
# 1                Deuterium-to-hydrogen number ratio.
# 2                 Helium-3-to-hydrogen number ratio.
# 3  Final mass-7 lithium abundance reported by Alt...
# 4  Lithium-6-to-hydrogen number ratio. Not used i...
# 5  Beryllium-7-to-hydrogen number ratio at the en...
# Comparación combinada:
#    observable        kind         value         sigma  \
# 0      Yp_He4  pynucastro  2.498880e-01           NaN
# 1      Yp_He4    AlterBBN  2.525000e-01  3.280000e-04
# 2      Yp_He4    observed  2.462000e-01  2.200000e-03
# 3         D/H  pynucastro  5.585615e-09           NaN
# 4         D/H    AlterBBN  2.674000e-05  5.462000e-07
# 5         D/H    observed  2.527000e-05  3.000000e-07
# 6       He3/H  pynucastro  5.263069e-06           NaN
# 7       He3/H    AlterBBN  1.067000e-05  1.730000e-07
# 8       He3/H    observed  1.100000e-05  2.000000e-06
# 9       Li7/H  pynucastro  9.465500e-08           NaN
# 10      Li7/H    AlterBBN  4.972000e-10  3.616000e-11
# 11      Li7/H    observed  1.600000e-10  3.000000e-11
#
#                       source  \
# 0   pynucastro light network
# 1   AlterBBN stand_cosmo.x 5
# 2                   Aver2021
# 3   pynucastro light network
# 4   AlterBBN stand_cosmo.x 5
# 5                  Cooke2018
# 6   pynucastro light network
# 7   AlterBBN stand_cosmo.x 5
# 8               Steigman2010
# 9   pynucastro light network
# 10  AlterBBN stand_cosmo.x 5
# 11       FieldsLithiumReview
#
#                                                 notes
# 0                                        column=X_He4
# 1                  Primordial helium-4 mass fraction.
# 2          observational reference used in the memory
# 3                                          column=D/H
# 4                 Deuterium-to-hydrogen number ratio.
# 5          observational reference used in the memory
# 6                                        column=He3/H
# 7                  Helium-3-to-hydrogen number ratio.
# 8          observational reference used in the memory
# 9                          column=Li7_plus_Be7_over_H
# 10  Final mass-7 lithium abundance reported by Alt...
# 11         observational reference used in the memory
# Resumen final:
#         model    Yp_He4           D/H     He3/H         Li7/H         Li6/H  \
# 0  pynucastro  0.249888  5.585615e-09  0.000005  9.465500e-08           NaN
# 1    AlterBBN  0.252500  2.674000e-05  0.000011  4.972000e-10  1.211000e-14
#
#           Be7/H                    source
# 0  9.465500e-08  pynucastro light network
# 1  4.652000e-10  AlterBBN stand_cosmo.x 5
