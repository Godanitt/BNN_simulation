# %% [markdown]
# # 05 — Benchmark con AlterBBN y comparación combinada
#
# Este notebook no recalcula AlterBBN: toma la salida que se obtuvo con `./stand_cosmo.x 5`, la guarda en CSV y genera las tablas/figuras combinadas:
#
# - `pynucastro` vs `AlterBBN` vs observación,
# - tabla compacta de resultados AlterBBN,
# - matriz de correlación de AlterBBN,
# - figuras finales usadas por la memoria.
#
# Debe ejecutarse **después** de los notebooks 00–04, porque lee los CSV finales de `pynucastro` y sobrescribe las figuras/tablas comparativas con la versión que incluye AlterBBN.

# %%
from pathlib import Path
import subprocess
import sys

script = Path('05_make_alterbbn_benchmark.py')
if not script.exists():
    raise FileNotFoundError(script)

subprocess.run([sys.executable, str(script)], check=True)
# Out:
# Wrote AlterBBN benchmark and combined comparison outputs.
# /mnt/data/BNN_edit/BNN_simulation/main/data/alterbbn_standard_results.csv
# /mnt/data/BNN_edit/BNN_simulation/main/data/comparison_pynucastro_alterbbn_observed.csv
# CompletedProcess(args=['/opt/pyvenv/bin/python3', '05_make_alterbbn_benchmark.py'], returncode=0)

# %%
import pandas as pd

print('AlterBBN:')
display(pd.read_csv('data/alterbbn_standard_results.csv'))

print('Comparación combinada:')
display(pd.read_csv('data/comparison_pynucastro_alterbbn_observed.csv'))

print('Resumen final:')
display(pd.read_csv('data/bbn_final_benchmark_combined.csv'))
# Out:
# AlterBBN:
#   observable  ...                                              notes
# 0     Yp_He4  ...                 Primordial helium-4 mass fraction.
# 1        D/H  ...                Deuterium-to-hydrogen number ratio.
# 2      He3/H  ...                 Helium-3-to-hydrogen number ratio.
# 3      Li7/H  ...  Final mass-7 lithium abundance reported by Alt...
# 4      Li6/H  ...  Lithium-6-to-hydrogen number ratio. Not used i...
# 5      Be7/H  ...  Beryllium-7-to-hydrogen number ratio at the en...
#
# [6 rows x 10 columns]
# Comparación combinada:
#    observable  ...                                              notes
# 0      Yp_He4  ...                                       column=X_He4
# 1      Yp_He4  ...                 Primordial helium-4 mass fraction.
# 2      Yp_He4  ...         observational reference used in the memory
# 3         D/H  ...                                         column=D/H
# 4         D/H  ...                Deuterium-to-hydrogen number ratio.
# ...
